# %%
amazon_weekly= get_data("amzn", start_date="12/04/2009", end_date="12/04/2019", index_as_date = True, interval="1wk")
amazon_weekly
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 amazon_weekly= get_data("amzn", start_date="12/04/2009", end_date="12/04/2019", index_as_date = True, interval="1wk")
#       2 amazon_weekly
#
# NameError: name 'get_data' is not defined

# %%
from yahoo_fin.stock_info import get_analysts_info

# %%
amazon_weekly= get_analysts_info("amzn")
amazon_weekly
# Out:
# {'Earnings Estimate':   Earnings Estimate  Current Qtr. (Jun 2023)  Next Qtr. (Sep 2023)  \
#  0   No. of Analysts                    37.00                 36.00
#  1     Avg. Estimate                     0.35                  0.40
#  2      Low Estimate                     0.14                  0.14
#  3     High Estimate                     0.47                  0.55
#  4      Year Ago EPS                    -0.20                  0.28
#
#     Current Year (2023)  Next Year (2024)
#  0                49.00             49.00
#  1                 1.59              2.58
#  2                 0.93              1.43
#  3                 2.06              4.09
#  4                -0.27              1.59  ,
#  'Revenue Estimate':           Revenue Estimate Current Qtr. (Jun 2023) Next Qtr. (Sep 2023)  \
#  0          No. of Analysts                      38                   37
#  1            Avg. Estimate                 131.43B              138.09B
# ...

# %%
from yahoo_fin.stock_info import get_company_info

# %%
x = get_company_info("aapl")   
x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 x = get_company_info("aapl")
#       2 x
#
# File ~\anaconda3\envs\dev\lib\site-packages\yahoo_fin\stock_info.py:1015, in get_company_info(ticker)
#    1013 site = f"https://finance.yahoo.com/quote/{ticker}/profile?p={ticker}"
#    1014 json_info = _parse_json(site)
# -> 1015 json_info = json_info["assetProfile"]
#    1016 info_frame = pd.DataFrame.from_dict(json_info,
#    1017                                     orient="index",
#    1018                                     columns=["Value"])
#    1019 info_frame = info_frame.drop("companyOfficers", axis="index")
#
# TypeError: string indices must be integers

# %%
from yahoo_fin.stock_info import get_data

# %%
msft_data = get_data('msft')

# %%
msft_data
# Out:
#                   open        high         low       close    adjclose  \
# 1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060524
# 1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062686
# 1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063767
# 1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062145
# 1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061065
# ...                ...         ...         ...         ...         ...
# 2023-07-13  339.559998  343.739990  339.019989  342.660004  342.660004
# 2023-07-14  347.589996  351.429993  344.309998  345.239990  345.239990
# 2023-07-17  345.679993  346.989990  342.200012  345.730011  345.730011
# 2023-07-18  345.829987  366.779999  342.170013  359.489990  359.489990
# 2023-07-19  361.750000  362.459991  352.434998  355.079987  355.079987
#
#                 volume ticker
# 1986-03-13  1031788800   MSFT
# 1986-03-14   308160000   MSFT
# ...
