# %%
#dependancies
import pandas as pd
from pathlib import Path
import os
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
import scipy.stats as st
import requests
import json
import pprint
import warnings
warnings.filterwarnings("ignore")

# %%
from yahoo_fin.stock_info import get_data

# %%
market_ticker = 'SPY'
start_date = '01/01/2017'
end_date = '31/12/2019'
interval = '1d'

# %%
stock_prices = get_data(market_ticker, start_date = start_date , end_date = end_date, interval=interval)

# %%
stock_prices
# Out:
#                   open        high         low       close    adjclose  \
# 2017-01-03  225.039993  225.830002  223.880005  225.240005  201.337418
# 2017-01-04  225.619995  226.750000  225.610001  226.580002  202.535156
# 2017-01-05  226.270004  226.580002  225.479996  226.399994  202.374252
# 2017-01-06  226.529999  227.750000  225.899994  227.210007  203.098343
# 2017-01-09  226.910004  227.070007  226.419998  226.460007  202.427887
# ...                ...         ...         ...         ...         ...
# 2019-12-23  321.589996  321.649994  321.059998  321.220001  303.922241
# 2019-12-24  321.470001  321.519989  320.899994  321.230011  303.931702
# 2019-12-26  321.649994  322.950012  321.640015  322.940002  305.549530
# 2019-12-27  323.739990  323.799988  322.279999  322.859985  305.473938
# 2019-12-30  322.950012  323.100006  320.549988  321.079987  303.789856
#
#               volume ticker
# 2017-01-03  91366500    SPY
# 2017-01-04  78744400    SPY
# ...

# %%
market_prices1D = stock_prices.plot(y='close', label='spy daily price')
plt.show()

# %%
stock_prices = get_data(market_ticker, start_date = start_date , end_date = end_date, interval='1wk')

# %%
stock_prices
# Out:
#                   open        high         low       close    adjclose  \
# 2017-01-01  225.039993  227.750000  223.880005  227.210007  203.098312
# 2017-01-08  226.910004  227.449997  224.960007  227.050003  202.955307
# 2017-01-15  226.309998  227.309998  225.410004  226.740005  202.678207
# 2017-01-22  226.740005  229.710007  225.270004  228.970001  204.671524
# 2017-01-29  228.169998  229.550003  226.320007  229.339996  205.002319
# ...                ...         ...         ...         ...         ...
# 2019-12-01  314.589996  315.309998  307.130005  314.869995  296.456635
# 2019-12-08  314.440002  318.670013  312.809998  317.320007  298.763367
# 2019-12-15  319.220001  321.970001  317.250000  320.730011  301.973907
# 2019-12-22  321.589996  323.799988  320.899994  322.859985  305.473877
# 2019-12-29  322.950012  323.100006  320.549988  321.079987  303.789703
#
#                volume ticker
# 2017-01-01  320049800    SPY
# 2017-01-08  320192700    SPY
# ...

# %%
market_prices1W = stock_prices.plot(y='close', label='spy weekly price')
plt.show()

# %%
healthcare_ticker = 'iyh'
start_date = '01/01/2017'
end_date = '31/12/2019'
interval = '1d'

# %%
stock_prices = get_data(healthcare_ticker, start_date = start_date , end_date = end_date, interval=interval)

# %%
stock_prices
# Out:
#                   open        high         low       close    adjclose  \
# 2017-01-03  144.050003  145.750000  144.050003  145.699997  134.044556
# 2017-01-04  146.169998  147.449997  145.990005  147.029999  135.268112
# 2017-01-05  147.000000  147.869995  146.899994  147.809998  135.985733
# 2017-01-06  147.929993  148.729996  147.589996  148.300003  136.436508
# 2017-01-09  148.559998  149.389999  148.149994  149.149994  137.218506
# ...                ...         ...         ...         ...         ...
# 2019-12-23  216.470001  217.160004  216.039993  217.020004  208.453247
# 2019-12-24  216.979996  216.979996  216.449997  216.860001  208.299545
# 2019-12-26  216.919998  216.929993  215.979996  216.440002  207.896118
# 2019-12-27  217.100006  217.100006  216.229996  216.339996  207.800064
# 2019-12-30  216.220001  216.660004  214.940002  215.080002  206.589798
#
#             volume ticker
# 2017-01-03  801500    IYH
# 2017-01-04   98900    IYH
# 2017-01-05   66300    IYH
# ...

# %%
healthcare_prices1D = stock_prices.plot(y='close', label='iyh daily price')
plt.show()

# %%
stock_prices = get_data(healthcare_ticker, start_date = start_date , end_date = end_date, interval='1wk')

# %%
stock_prices
# Out:
#                   open        high         low       close    adjclose  \
# 2017-01-01  144.050003  148.729996  144.050003  148.300003  136.436523
# 2017-01-08  148.559998  150.410004  146.820007  148.470001  136.592926
# 2017-01-15  148.009995  148.130005  146.050003  146.199997  134.504547
# 2017-01-22  145.919998  146.309998  143.889999  146.149994  134.458527
# 2017-01-29  145.929993  149.789993  144.750000  149.750000  137.770554
# ...                ...         ...         ...         ...         ...
# 2019-12-01  209.630005  211.910004  206.770004  211.220001  202.266220
# 2019-12-08  211.059998  213.110001  209.429993  211.789993  202.812042
# 2019-12-15  212.500000  216.500000  212.500000  216.089996  206.929764
# 2019-12-22  216.470001  217.160004  215.979996  216.339996  207.800064
# 2019-12-29  216.220001  216.660004  214.940002  215.080002  206.589798
#
#              volume ticker
# 2017-01-01  1085800    IYH
# 2017-01-08   513100    IYH
# 2017-01-15   921000    IYH
# ...

# %%
healthcare_prices1W = stock_prices.plot(y='close', label='iyh weekly price')
plt.show()

# %%
market_ticker = 'SPY'
start_date = '01/01/2020'
end_date = '31/12/2022'
interval = '1d'

# %%
stock_prices = get_data(market_ticker, start_date = start_date , end_date = end_date, interval=interval)

# %%
stock_prices
# Out:
#                   open        high         low       close    adjclose  \
# 2020-01-02  323.540009  324.890015  322.529999  324.869995  307.375732
# 2020-01-03  321.160004  323.640015  321.100006  322.410004  305.048126
# 2020-01-06  320.489990  323.730011  320.359985  323.640015  306.211945
# 2020-01-07  323.019989  323.540009  322.239990  322.730011  305.350922
# 2020-01-08  322.940002  325.779999  322.670013  324.450012  306.978241
# ...                ...         ...         ...         ...         ...
# 2022-12-23  379.649994  383.059998  378.029999  382.910004  380.042480
# 2022-12-27  382.790009  383.149994  379.649994  381.399994  378.543793
# 2022-12-28  381.329987  383.390015  376.420013  376.660004  373.839264
# 2022-12-29  379.630005  384.350006  379.079987  383.440002  380.568512
# 2022-12-30  380.640015  382.579987  378.429993  382.429993  379.566040
#
#               volume ticker
# 2020-01-02  59151200    SPY
# 2020-01-03  77709700    SPY
# ...

# %%
market_prices1D = stock_prices.plot(y='close', label='spy daily price')
plt.show()

# %%
stock_prices = get_data(market_ticker, start_date = start_date , end_date = end_date, interval='1wk')

# %%
stock_prices
# Out:
#                   open        high         low       close    adjclose  \
# 2020-01-02  323.540009  324.890015  322.529999  324.869995  307.375732
# 2020-01-03  321.160004  323.640015  321.100006  322.410004  305.048126
# 2020-01-06  320.489990  323.730011  320.359985  323.640015  306.211945
# 2020-01-07  323.019989  323.540009  322.239990  322.730011  305.350922
# 2020-01-08  322.940002  325.779999  322.670013  324.450012  306.978241
# ...                ...         ...         ...         ...         ...
# 2022-12-23  379.649994  383.059998  378.029999  382.910004  380.042480
# 2022-12-27  382.790009  383.149994  379.649994  381.399994  378.543793
# 2022-12-28  381.329987  383.390015  376.420013  376.660004  373.839264
# 2022-12-29  379.630005  384.350006  379.079987  383.440002  380.568512
# 2022-12-30  380.640015  382.579987  378.429993  382.429993  379.566040
#
#               volume ticker
# 2020-01-02  59151200    SPY
# 2020-01-03  77709700    SPY
# ...

# %%
market_prices1W = stock_prices.plot(y='close', label='spy weekly price')
plt.show()

# %%
healthcare_ticker = 'iyh'
start_date = '01/01/2020'
end_date = '31/12/2022'
interval = '1d'

# %%
stock_prices = get_data(healthcare_ticker, start_date = start_date , end_date = end_date, interval=interval)

# %%
stock_prices
# Out:
#                   open        high         low       close    adjclose  \
# 2020-01-02  216.300003  216.300003  214.570007  216.149994  207.617538
# 2020-01-03  213.550003  215.389999  212.880005  214.229996  205.773346
# 2020-01-06  213.330002  215.779999  213.330002  215.779999  207.262146
# 2020-01-07  215.229996  215.630005  214.139999  215.169998  206.676224
# 2020-01-08  215.270004  217.589996  215.270004  216.589996  208.040192
# ...                ...         ...         ...         ...         ...
# 2022-12-23  284.089996  284.160004  282.320007  283.899994  282.507141
# 2022-12-27  283.980011  284.309998  282.579987  283.000000  281.611572
# 2022-12-28  283.019989  285.200012  281.260010  281.260010  279.880096
# 2022-12-29  283.309998  286.049988  282.640015  284.600006  283.203735
# 2022-12-30  283.839996  283.839996  280.769989  283.709991  282.318085
#
#             volume ticker
# 2020-01-02  514500    IYH
# 2020-01-03   46400    IYH
# 2020-01-06   55900    IYH
# ...

# %%
healthcare_prices1D = stock_prices.plot(y='close', label='iyh daily price')
plt.show()

# %%
stock_prices = get_data(healthcare_ticker, start_date = start_date , end_date = end_date, interval='1wk')

# %%
stock_prices
# Out:
#                   open        high         low       close    adjclose  \
# 2020-01-01  216.300003  216.300003  212.880005  215.169998  206.676254
# 2020-01-08  215.270004  218.869995  215.270004  218.160004  209.548203
# 2020-01-15  218.449997  221.729996  218.449997  221.240005  212.506638
# 2020-01-22  221.740005  222.259995  213.289993  216.160004  207.627151
# 2020-01-29  216.710007  217.220001  209.380005  215.699997  207.185287
# ...                ...         ...         ...         ...         ...
# 2022-11-30  283.470001  291.910004  281.500000  285.540009  283.346588
# 2022-12-07  285.980011  294.070007  285.980011  290.609985  288.377594
# 2022-12-14  290.570007  293.459991  279.029999  280.679993  279.302948
# 2022-12-21  282.390015  285.179993  280.769989  283.000000  281.611572
# 2022-12-28  283.019989  286.049988  280.769989  283.709991  282.318085
#
#             volume ticker
# 2020-01-01  644700    IYH
# 2020-01-08  200300    IYH
# 2020-01-15  158900    IYH
# ...

# %%
healthcare_prices1W = stock_prices.plot(y='close', label='iyh weekly price')
plt.show()
