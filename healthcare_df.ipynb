# %%
# import modules

import pandas as pd
import glob

# %%
# combining all the csv files
# luckily the structure is all the same so we're able to use the glod module

# using glob module to get list
# of all csv files in the target directory
health_stocks_csv = glob.glob('../eda-project-1-group-4/project-1_data/*.csv')

# initializing dataframe
health_stocks_csv_df = []

# looping through the csv files
for csv in health_stocks_csv:
    health_stocks_csv_df.append(pd.read_csv(csv))
    
# concatenating all dataframes

combined_health_stocks_csv = pd.concat(health_stocks_csv_df, ignore_index=True)
combined_health_stocks_csv.head()
# Out:
#   Symbol                    Description  GICS sector  Category1  \
# 0    NVO          Novo Nordisk A/S ADRs  Health Care  US Equity
# 1   REGN  Regeneron Pharmaceuticals Inc  Health Care  US Equity
# 2   VRTX     Vertex Pharmaceuticals Inc  Health Care  US Equity
# 3   SGEN           Seattle Genetics Inc  Health Care  US Equity
# 4   BNTX              BioNTech SE  ADRs  Health Care  US Equity
#
#        Category2  Category3        Market Cap Average Volume  Actions
# 0           ADRs  Large cap  $260,652,723,120      1,565,762  Analyze
# 1  Common stocks  Large cap   $86,238,124,754        637,527  Analyze
# 2  Common stocks  Large cap   $78,348,616,645      1,110,826  Analyze
# 3  Common stocks  Large cap   $37,002,973,603      1,468,401  Analyze
# 4           ADRs  Large cap   $31,469,610,717        637,153  Analyze

# %%
# dropping unneccesary columns

combined_health_stocks_csv = combined_health_stocks_csv.drop(columns = ['Actions', 'Category1', 'Category2', 'Description'])
combined_health_stocks_csv
# Out:
#      Symbol             GICS sector  Category3        Market Cap  \
# 0       NVO             Health Care  Large cap  $260,652,723,120
# 1      REGN             Health Care  Large cap   $86,238,124,754
# 2      VRTX             Health Care  Large cap   $78,348,616,645
# 3      SGEN             Health Care  Large cap   $37,002,973,603
# 4      BNTX             Health Care  Large cap   $31,469,610,717
# ...     ...                     ...        ...               ...
# 1312   LFMD        Consumer Staples  Micro cap       $46,236,157
# 1313   LFLY  Communication Services  Micro cap       $15,713,960
# 1314   GNLN  Consumer Discretionary  Micro cap        $5,361,583
# 1315   MEDS  Consumer Discretionary  Micro cap        $3,486,129
# 1316   BIMI             Industrials  Micro cap        $2,331,212
#
#      Average Volume
# 0         1,565,762
# 1           637,527
# 2         1,110,826
# 3         1,468,401
# 4           637,153
# ...             ...
# 1312         80,472
# 1313        230,781
# 1314        113,697
# 1315         88,184
# 1316        112,285
#
# [1317 rows x 5 columns]

# %%
# now to drop stocks in Category1 column if they aren't healthcare

cleaned_combined_health_stocks_csv = combined_health_stocks_csv[combined_health_stocks_csv['GICS sector'] == 'Health Care']
cleaned_combined_health_stocks_csv
# Out:
#      Symbol  GICS sector  Category3        Market Cap Average Volume
# 0       NVO  Health Care  Large cap  $260,652,723,120      1,565,762
# 1      REGN  Health Care  Large cap   $86,238,124,754        637,527
# 2      VRTX  Health Care  Large cap   $78,348,616,645      1,110,826
# 3      SGEN  Health Care  Large cap   $37,002,973,603      1,468,401
# 4      BNTX  Health Care  Large cap   $31,469,610,717        637,153
# ...     ...          ...        ...               ...            ...
# 1301   NURO  Health Care  Micro cap       $11,297,730         17,334
# 1303   NXGL  Health Care  Micro cap        $9,194,186         21,689
# 1304   GCTK  Health Care  Micro cap        $6,403,000         39,826
# 1306   STVN  Health Care    Mid cap    $6,803,331,629        321,949
# 1310   HITI  Health Care  Micro cap       $78,475,890        256,863
#
# [1277 rows x 5 columns]

# %%
# looking for and deleting duplicates

duplicates = cleaned_combined_health_stocks_csv.duplicated()
duplicates

# there aren't any
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1301    False
# 1303    False
# 1304    False
# 1306    False
# 1310    False
# Length: 1277, dtype: bool

# %%
# saving the dataframe as csv so we can read it in other files

cleaned_combined_health_stocks_csv.to_csv('cleaned_combined_healthcare_stocks.csv')

# %%
# now we're missing the stock price performance data
# need to look

# going to work on it on a different file
